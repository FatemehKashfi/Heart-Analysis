# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df[['age']]
# Out:
#         age
# 0     29.00
# 1      0.92
# 2      2.00
# 3     30.00
# 4     25.00
# ...     ...
# 1304  14.50
# 1305    NaN
# 1306  26.50
# 1307  27.00
# 1308  29.00
#
# [1309 rows x 1 columns]

# %%
df['age']
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305      NaN
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
df['age'][5:20:2]
# Out:
# 5     48.0
# 7     39.0
# 9     71.0
# 11    18.0
# 13    26.0
# 15     NaN
# 17    50.0
# 19    36.0
# Name: age, dtype: float64

# %%
df.survived[0:5]
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: survived, dtype: int64

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
df['survived'].value_counts(normalize =True)*100
# Out:
# survived
# 0    61.802903
# 1    38.197097
# Name: proportion, dtype: float64

# %%
pd.crosstab(df.sex,df.survived, normalize= "index")
# Out:
# survived         0         1
# sex
# female    0.272532  0.727468
# male      0.809015  0.190985

# %%
pd.crosstab(df.sex,df.survived, normalize= "columns")
# Out:
# survived         0      1
# sex
# female    0.156984  0.678
# male      0.843016  0.322

# %%
below_5_years= df[df.age<=5]
below_5_years["survived"].value_counts()
# Out:
# survived
# 1    37
# 0    19
# Name: count, dtype: int64

# %%
df[df.name.str.contains('Ali', case= False)]
# Out:
#       pclass  survived                                               name  \
# 23         1         1                              Bidois, Miss. Rosalie
# 73         1         1                               Cleaver, Miss. Alice
# 111        1         1                     Fortune, Miss. Alice Elizabeth
# 129        1         1                               Geiger, Miss. Amalie
# 163        1         1  Holverson, Mrs. Alexander Oskar (Mary Aline To...
# 181        1         1                        Leader, Dr. Alice (Farnham)
# 263        1         1          Silvey, Mrs. William Baird (Alice Munger)
# 286        1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 309        1         1                           Wick, Miss. Mary Natalie
# 319        1         1                          Wilson, Miss. Helen Alice
# 371        2         1                      Christy, Mrs. (Alice Frances)
# 437        2         1                                Herman, Miss. Alice
# ...

# %%
df.embarked.unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df['embarked'].value_counts()
# Out:
# embarked
# S    914
# C    270
# Q    123
# Name: count, dtype: int64

# %%
df[(df.survived==1)&(df.age<=5)]
# Out:
#       pclass  survived                                      name     sex  \
# 1          1         1            Allison, Master. Hudson Trevor    male
# 94         1         1                 Dodge, Master. Washington    male
# 339        2         1                 Becker, Master. Richard F    male
# 340        2         1               Becker, Miss. Marion Louise  female
# 359        2         1             Caldwell, Master. Alden Gates    male
# 427        2         1                 Hamalainen, Master. Viljo    male
# 478        2         1                     Laroche, Miss. Louise  female
# 479        2         1  Laroche, Miss. Simonne Marie Anne Andree  female
# 492        2         1                     Mallet, Master. Andre    male
# 514        2         1            Navratil, Master. Edmond Roger    male
# 515        2         1                Navratil, Master. Michel M    male
# 540        2         1                  Quick, Miss. Phyllis May  female
# ...

# %%
df[(df.survived ==1)&(df.age<=5)][['age','sex','survived']]
# Out:
#        age     sex  survived
# 1     0.92    male         1
# 94    4.00    male         1
# 339   1.00    male         1
# 340   4.00  female         1
# 359   0.83    male         1
# 427   0.67    male         1
# 478   1.00  female         1
# 479   3.00  female         1
# 492   1.00    male         1
# 514   2.00    male         1
# 515   3.00    male         1
# 540   2.00  female         1
# 548   0.83    male         1
# 549   3.00    male         1
# 587   2.00    male         1
# 588   4.00  female         1
# 590   0.92  female         1
# 591   5.00  female         1
# 611   0.83    male         1
# 641   3.00    male         1
# 643   5.00  female         1
# 657   0.75  female         1
# 658   0.75  female         1
# 659   5.00  female         1
# 734   3.00    male         1
# 762   1.00    male         1
# 763   0.17  female         1
# 794   5.00  female         1
# 866   2.00  female         1
# 894   4.00    male         1
# 895   1.00  female         1
# ...

# %%
df.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: fare, dtype: float64

# %%
calss_gender_age = df.groupby(['pclass', 'sex'])['fare'].mean().reset_index
calss_gender_age
# Out:
# <bound method Series.reset_index of pclass  sex
# 1       female    109.412385
#         male       69.888385
# 2       female     23.234827
#         male       19.904946
# 3       female     15.324250
#         male       12.415462
# Name: fare, dtype: float64>

# %%
df.iloc[:3,:5]
# Out:
#    pclass  survived                            name     sex    age
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.00
# 1       1         1  Allison, Master. Hudson Trevor    male   0.92
# 2       1         0    Allison, Miss. Helen Loraine  female   2.00

# %%
col = [True, True, False, True,True, True, False, True,True, True, False, True,False,False]
df.iloc[1:5, col]
# Out:
#    pclass  survived     sex    age  sibsp  ticket    fare    cabin boat
# 1       1         1    male   0.92      1  113781  151.55  C22 C26   11
# 2       1         0  female   2.00      1  113781  151.55  C22 C26  NaN
# 3       1         0    male  30.00      1  113781  151.55  C22 C26  NaN
# 4       1         0  female  25.00      1  113781  151.55  C22 C26  NaN

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df2 = pd.read_csv("titanic.csv", index_col = "name")
df2
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
# ...

# %% [markdown]
# ##

# %%
df2.loc["Allen, Miss. Elisabeth Walton"]
# Out:
# pclass                  1
# survived                1
# sex                female
# age                  29.0
# sibsp                   0
# parch                   0
# ticket              24160
# fare             211.3375
# cabin                  B5
# embarked                S
# boat                    2
# body                  NaN
# home.dest    St Louis, MO
# Name: Allen, Miss. Elisabeth Walton, dtype: object

# %%
df.query('survived == 1 and embarked == "S" and pclass == 1 and fare >200')
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 24        1         1                                  Bird, Miss. Ellen
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# 112       1         1                         Fortune, Miss. Ethel Flora
# 113       1         1                         Fortune, Miss. Mabel Helen
# 116       1         1                Fortune, Mrs. Mark (Mary McDougald)
# 180       1         1                             Kreuchen, Miss. Emilie
# 193       1         1                  Madill, Miss. Georgette Alexandra
# 238       1         1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 0    female  29.0      0      0     24160  211.3375           B5        S
# 24   female  29.0      0      0  PC 17483  221.7792          C97        S
# ...

# %%
df.loc[(df.survived==1)&(df.embarked=='S')&(df.fare>200)&(df.pclass==1)]
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 24        1         1                                  Bird, Miss. Ellen
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# 112       1         1                         Fortune, Miss. Ethel Flora
# 113       1         1                         Fortune, Miss. Mabel Helen
# 116       1         1                Fortune, Mrs. Mark (Mary McDougald)
# 180       1         1                             Kreuchen, Miss. Emilie
# 193       1         1                  Madill, Miss. Georgette Alexandra
# 238       1         1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 0    female  29.0      0      0     24160  211.3375           B5        S
# 24   female  29.0      0      0  PC 17483  221.7792          C97        S
# ...

# %%
df[(df['pclass']==1)&(df['survived']==1)&(df['embarked']=='S')&(df['fare']>200)]
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 24        1         1                                  Bird, Miss. Ellen
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# 112       1         1                         Fortune, Miss. Ethel Flora
# 113       1         1                         Fortune, Miss. Mabel Helen
# 116       1         1                Fortune, Mrs. Mark (Mary McDougald)
# 180       1         1                             Kreuchen, Miss. Emilie
# 193       1         1                  Madill, Miss. Georgette Alexandra
# 238       1         1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 0    female  29.0      0      0     24160  211.3375           B5        S
# 24   female  29.0      0      0  PC 17483  221.7792          C97        S
# ...
