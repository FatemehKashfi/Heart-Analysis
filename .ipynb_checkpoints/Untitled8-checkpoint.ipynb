# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Mahsa\heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df['chol'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
 plt.scatter(x=df["chol"], y=df["age"])

# %%
sns.jointplot(x=df["chol"], y= df["age"])

# %%
q1 = df["chol"].quantile(0.25)
q2 = df["chol"].quantile(0.50)
q3 = df["chol"].quantile(0.75)
df_final = df[((df['chol']<(q1-1.5*(q3-q1)))|(df['chol']>(q3+1.5*(q3-q1))))]
df_final
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 123   65    0   2       140   417    1        0      157      0      0.8
# 158   67    0   2       115   564    0        0      160      0      1.6
# 179   56    0   0       134   409    0        0      150      1      1.9
# 192   67    0   2       115   564    0        0      160      0      1.6
# 255   62    0   0       140   394    0        0      157      0      1.2
# 450   63    0   0       150   407    0        0      154      0      4.0
# 464   67    0   2       115   564    0        0      160      0      1.6
# 481   63    0   0       150   407    0        0      154      0      4.0
# 542   62    0   0       140   394    0        0      157      0      1.2
# 578   62    0   0       140   394    0        0      157      0      1.2
# 641   56    0   0       134   409    0        0      150      1      1.9
# 665   65    0   2       140   417    1        0      157      0      0.8
# ...

# %%
len(df_final)
# Out:
# 16

# %%
((df['age']-df['age'].mean())/df['age'].std()).abs()
# Out:
# 0       0.268306
# 1       0.158080
# 2       1.715758
# 3       0.723726
# 4       0.833952
#           ...
# 1020    0.503275
# 1021    0.613500
# 1022    0.819434
# 1023    0.488757
# 1024    0.047854
# Name: age, Length: 1025, dtype: float64

# %%
df_o =df[((df['age']-df['age'].mean())/df['age'].std()).abs() <3]

# %%
print(df.shape, df_o.shape)
# Out:
# (1025, 14) (1025, 14)
